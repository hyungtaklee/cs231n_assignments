# %%
# Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = '/home/cclab/cs231n/assignments/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append(FOLDERNAME)

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd $FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd $FOLDERNAME
# Out:
# /home/cclab/cs231n/assignments/assignment1/cs231n/datasets
# /home/cclab/cs231n/assignments/assignment1

# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [3.75e-7, 4.375e-7, 5e-7, 5.625e-7, 6.25e-7, 6.875e-7, 7.5e-7, 8.125e-7, 8.75e-7]
regularization_strengths = [7.5e3, 7.625e3, 8.75e3, 9.375e3, 1e4, 1.125e4, 1.25e4]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for lr in learning_rates:
    for reg in regularization_strengths:
        print('testing for lr: %.2e, reg %.2e' % (lr, reg), end='')
        svm = LinearSVM()
        loss_hist = svm.train(X_test_feats, y_test,
                learning_rate=lr, reg=reg, num_iters=1000)

        y_train_pred = svm.predict(X_train_feats)
        train_acc = np.mean(y_train_pred == y_train)

        y_val_pred = svm.predict(X_val_feats)
        val_acc = np.mean(y_val == y_val_pred)
        
        results[(lr, reg)] = (train_acc, val_acc)

        print(' achieved train_acc: %f, val_acc: %f' % (train_acc, val_acc))

        if val_acc > best_val:
            best_val = val_acc
            best_svm = svm

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved: %f' % best_val)
# Out:
# testing for lr: 3.75e-07, reg 7.50e+03 achieved train_acc: 0.379755, val_acc: 0.393000
# testing for lr: 3.75e-07, reg 7.62e+03 achieved train_acc: 0.379980, val_acc: 0.391000
# testing for lr: 3.75e-07, reg 8.75e+03 achieved train_acc: 0.378776, val_acc: 0.392000
# testing for lr: 3.75e-07, reg 9.38e+03 achieved train_acc: 0.382551, val_acc: 0.386000
# testing for lr: 3.75e-07, reg 1.00e+04 achieved train_acc: 0.377755, val_acc: 0.387000
# testing for lr: 3.75e-07, reg 1.12e+04 achieved train_acc: 0.380265, val_acc: 0.392000
# testing for lr: 3.75e-07, reg 1.25e+04 achieved train_acc: 0.379714, val_acc: 0.379000
# testing for lr: 4.37e-07, reg 7.50e+03 achieved train_acc: 0.377408, val_acc: 0.383000
# testing for lr: 4.37e-07, reg 7.62e+03 achieved train_acc: 0.378755, val_acc: 0.392000
# testing for lr: 4.37e-07, reg 8.75e+03 achieved train_acc: 0.379163, val_acc: 0.379000
# testing for lr: 4.37e-07, reg 9.38e+03 achieved train_acc: 0.377816, val_acc: 0.384000
# testing for lr: 4.37e-07, reg 1.00e+04 achieved train_acc: 0.381224, val_acc: 0.392000
# testing for lr: 4.37e-07, reg 1.12e+04 achieved train_acc: 0.381510, val_acc: 0.390000
# testing for lr: 4.37e-07, reg 1.25e+04 achieved train_acc: 0.378653, val_acc: 0.381000
# testing for lr: 5.00e-07, reg 7.50e+03 achieved train_acc: 0.382898, val_acc: 0.391000
# testing for lr: 5.00e-07, reg 7.62e+03 achieved train_acc: 0.379837, val_acc: 0.385000
# testing for lr: 5.00e-07, reg 8.75e+03 achieved train_acc: 0.378551, val_acc: 0.393000
# testing for lr: 5.00e-07, reg 9.38e+03 achieved train_acc: 0.376245, val_acc: 0.390000
# testing for lr: 5.00e-07, reg 1.00e+04 achieved train_acc: 0.379612, val_acc: 0.386000
# testing for lr: 5.00e-07, reg 1.12e+04 achieved train_acc: 0.379918, val_acc: 0.380000
# testing for lr: 5.00e-07, reg 1.25e+04 achieved train_acc: 0.377469, val_acc: 0.383000
# testing for lr: 5.63e-07, reg 7.50e+03 achieved train_acc: 0.376469, val_acc: 0.378000
# testing for lr: 5.63e-07, reg 7.62e+03 achieved train_acc: 0.383265, val_acc: 0.393000
# testing for lr: 5.63e-07, reg 8.75e+03 achieved train_acc: 0.377000, val_acc: 0.384000
# testing for lr: 5.63e-07, reg 9.38e+03 achieved train_acc: 0.378224, val_acc: 0.394000
# testing for lr: 5.63e-07, reg 1.00e+04 achieved train_acc: 0.377143, val_acc: 0.389000
# testing for lr: 5.63e-07, reg 1.12e+04 achieved train_acc: 0.381653, val_acc: 0.386000
# testing for lr: 5.63e-07, reg 1.25e+04 achieved train_acc: 0.378265, val_acc: 0.393000
# testing for lr: 6.25e-07, reg 7.50e+03 achieved train_acc: 0.379490, val_acc: 0.388000
# testing for lr: 6.25e-07, reg 7.62e+03 achieved train_acc: 0.380510, val_acc: 0.390000
# testing for lr: 6.25e-07, reg 8.75e+03 achieved train_acc: 0.377939, val_acc: 0.389000
# testing for lr: 6.25e-07, reg 9.38e+03 achieved train_acc: 0.379061, val_acc: 0.383000
# testing for lr: 6.25e-07, reg 1.00e+04 achieved train_acc: 0.379388, val_acc: 0.388000
# testing for lr: 6.25e-07, reg 1.12e+04 achieved train_acc: 0.377633, val_acc: 0.388000
# testing for lr: 6.25e-07, reg 1.25e+04 achieved train_acc: 0.377571, val_acc: 0.389000
# testing for lr: 6.87e-07, reg 7.50e+03 achieved train_acc: 0.380653, val_acc: 0.385000
# testing for lr: 6.87e-07, reg 7.62e+03 achieved train_acc: 0.379980, val_acc: 0.388000
# testing for lr: 6.87e-07, reg 8.75e+03 achieved train_acc: 0.374184, val_acc: 0.381000
# testing for lr: 6.87e-07, reg 9.38e+03 achieved train_acc: 0.381388, val_acc: 0.390000
# testing for lr: 6.87e-07, reg 1.00e+04 achieved train_acc: 0.377694, val_acc: 0.383000
# testing for lr: 6.87e-07, reg 1.12e+04 achieved train_acc: 0.377388, val_acc: 0.386000
# testing for lr: 6.87e-07, reg 1.25e+04 achieved train_acc: 0.376551, val_acc: 0.389000
# testing for lr: 7.50e-07, reg 7.50e+03 achieved train_acc: 0.380265, val_acc: 0.382000
# testing for lr: 7.50e-07, reg 7.62e+03 achieved train_acc: 0.377510, val_acc: 0.388000
# testing for lr: 7.50e-07, reg 8.75e+03 achieved train_acc: 0.378918, val_acc: 0.384000
# testing for lr: 7.50e-07, reg 9.38e+03 achieved train_acc: 0.383959, val_acc: 0.390000
# testing for lr: 7.50e-07, reg 1.00e+04 achieved train_acc: 0.375041, val_acc: 0.385000
# testing for lr: 7.50e-07, reg 1.12e+04 achieved train_acc: 0.382204, val_acc: 0.392000
# testing for lr: 7.50e-07, reg 1.25e+04 achieved train_acc: 0.377041, val_acc: 0.390000
# testing for lr: 8.12e-07, reg 7.50e+03 achieved train_acc: 0.378755, val_acc: 0.381000
# testing for lr: 8.12e-07, reg 7.62e+03 achieved train_acc: 0.378980, val_acc: 0.385000
# testing for lr: 8.12e-07, reg 8.75e+03 achieved train_acc: 0.381245, val_acc: 0.391000
# testing for lr: 8.12e-07, reg 9.38e+03 achieved train_acc: 0.375980, val_acc: 0.383000
# testing for lr: 8.12e-07, reg 1.00e+04 achieved train_acc: 0.380388, val_acc: 0.380000
# testing for lr: 8.12e-07, reg 1.12e+04 achieved train_acc: 0.377551, val_acc: 0.381000
# testing for lr: 8.12e-07, reg 1.25e+04 achieved train_acc: 0.379143, val_acc: 0.394000
# testing for lr: 8.75e-07, reg 7.50e+03 achieved train_acc: 0.379184, val_acc: 0.378000
# testing for lr: 8.75e-07, reg 7.62e+03 achieved train_acc: 0.379204, val_acc: 0.388000
# testing for lr: 8.75e-07, reg 8.75e+03 achieved train_acc: 0.378939, val_acc: 0.391000
# testing for lr: 8.75e-07, reg 9.38e+03 achieved train_acc: 0.379449, val_acc: 0.389000
# testing for lr: 8.75e-07, reg 1.00e+04 achieved train_acc: 0.382224, val_acc: 0.388000
# testing for lr: 8.75e-07, reg 1.12e+04 achieved train_acc: 0.375694, val_acc: 0.387000
# testing for lr: 8.75e-07, reg 1.25e+04 achieved train_acc: 0.374612, val_acc: 0.374000
# lr 3.750000e-07 reg 7.500000e+03 train accuracy: 0.379755 val accuracy: 0.393000
# lr 3.750000e-07 reg 7.625000e+03 train accuracy: 0.379980 val accuracy: 0.391000
# lr 3.750000e-07 reg 8.750000e+03 train accuracy: 0.378776 val accuracy: 0.392000
# lr 3.750000e-07 reg 9.375000e+03 train accuracy: 0.382551 val accuracy: 0.386000
# lr 3.750000e-07 reg 1.000000e+04 train accuracy: 0.377755 val accuracy: 0.387000
# lr 3.750000e-07 reg 1.125000e+04 train accuracy: 0.380265 val accuracy: 0.392000
# lr 3.750000e-07 reg 1.250000e+04 train accuracy: 0.379714 val accuracy: 0.379000
# lr 4.375000e-07 reg 7.500000e+03 train accuracy: 0.377408 val accuracy: 0.383000
# lr 4.375000e-07 reg 7.625000e+03 train accuracy: 0.378755 val accuracy: 0.392000
# lr 4.375000e-07 reg 8.750000e+03 train accuracy: 0.379163 val accuracy: 0.379000
# lr 4.375000e-07 reg 9.375000e+03 train accuracy: 0.377816 val accuracy: 0.384000
# lr 4.375000e-07 reg 1.000000e+04 train accuracy: 0.381224 val accuracy: 0.392000
# lr 4.375000e-07 reg 1.125000e+04 train accuracy: 0.381510 val accuracy: 0.390000
# lr 4.375000e-07 reg 1.250000e+04 train accuracy: 0.378653 val accuracy: 0.381000
# lr 5.000000e-07 reg 7.500000e+03 train accuracy: 0.382898 val accuracy: 0.391000
# lr 5.000000e-07 reg 7.625000e+03 train accuracy: 0.379837 val accuracy: 0.385000
# lr 5.000000e-07 reg 8.750000e+03 train accuracy: 0.378551 val accuracy: 0.393000
# lr 5.000000e-07 reg 9.375000e+03 train accuracy: 0.376245 val accuracy: 0.390000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.379612 val accuracy: 0.386000
# lr 5.000000e-07 reg 1.125000e+04 train accuracy: 0.379918 val accuracy: 0.380000
# lr 5.000000e-07 reg 1.250000e+04 train accuracy: 0.377469 val accuracy: 0.383000
# lr 5.625000e-07 reg 7.500000e+03 train accuracy: 0.376469 val accuracy: 0.378000
# lr 5.625000e-07 reg 7.625000e+03 train accuracy: 0.383265 val accuracy: 0.393000
# lr 5.625000e-07 reg 8.750000e+03 train accuracy: 0.377000 val accuracy: 0.384000
# lr 5.625000e-07 reg 9.375000e+03 train accuracy: 0.378224 val accuracy: 0.394000
# lr 5.625000e-07 reg 1.000000e+04 train accuracy: 0.377143 val accuracy: 0.389000
# lr 5.625000e-07 reg 1.125000e+04 train accuracy: 0.381653 val accuracy: 0.386000
# lr 5.625000e-07 reg 1.250000e+04 train accuracy: 0.378265 val accuracy: 0.393000
# lr 6.250000e-07 reg 7.500000e+03 train accuracy: 0.379490 val accuracy: 0.388000
# lr 6.250000e-07 reg 7.625000e+03 train accuracy: 0.380510 val accuracy: 0.390000
# lr 6.250000e-07 reg 8.750000e+03 train accuracy: 0.377939 val accuracy: 0.389000
# lr 6.250000e-07 reg 9.375000e+03 train accuracy: 0.379061 val accuracy: 0.383000
# lr 6.250000e-07 reg 1.000000e+04 train accuracy: 0.379388 val accuracy: 0.388000
# lr 6.250000e-07 reg 1.125000e+04 train accuracy: 0.377633 val accuracy: 0.388000
# lr 6.250000e-07 reg 1.250000e+04 train accuracy: 0.377571 val accuracy: 0.389000
# lr 6.875000e-07 reg 7.500000e+03 train accuracy: 0.380653 val accuracy: 0.385000
# lr 6.875000e-07 reg 7.625000e+03 train accuracy: 0.379980 val accuracy: 0.388000
# lr 6.875000e-07 reg 8.750000e+03 train accuracy: 0.374184 val accuracy: 0.381000
# lr 6.875000e-07 reg 9.375000e+03 train accuracy: 0.381388 val accuracy: 0.390000
# lr 6.875000e-07 reg 1.000000e+04 train accuracy: 0.377694 val accuracy: 0.383000
# lr 6.875000e-07 reg 1.125000e+04 train accuracy: 0.377388 val accuracy: 0.386000
# lr 6.875000e-07 reg 1.250000e+04 train accuracy: 0.376551 val accuracy: 0.389000
# lr 7.500000e-07 reg 7.500000e+03 train accuracy: 0.380265 val accuracy: 0.382000
# lr 7.500000e-07 reg 7.625000e+03 train accuracy: 0.377510 val accuracy: 0.388000
# lr 7.500000e-07 reg 8.750000e+03 train accuracy: 0.378918 val accuracy: 0.384000
# lr 7.500000e-07 reg 9.375000e+03 train accuracy: 0.383959 val accuracy: 0.390000
# lr 7.500000e-07 reg 1.000000e+04 train accuracy: 0.375041 val accuracy: 0.385000
# lr 7.500000e-07 reg 1.125000e+04 train accuracy: 0.382204 val accuracy: 0.392000
# lr 7.500000e-07 reg 1.250000e+04 train accuracy: 0.377041 val accuracy: 0.390000
# lr 8.125000e-07 reg 7.500000e+03 train accuracy: 0.378755 val accuracy: 0.381000
# lr 8.125000e-07 reg 7.625000e+03 train accuracy: 0.378980 val accuracy: 0.385000
# lr 8.125000e-07 reg 8.750000e+03 train accuracy: 0.381245 val accuracy: 0.391000
# lr 8.125000e-07 reg 9.375000e+03 train accuracy: 0.375980 val accuracy: 0.383000
# lr 8.125000e-07 reg 1.000000e+04 train accuracy: 0.380388 val accuracy: 0.380000
# lr 8.125000e-07 reg 1.125000e+04 train accuracy: 0.377551 val accuracy: 0.381000
# lr 8.125000e-07 reg 1.250000e+04 train accuracy: 0.379143 val accuracy: 0.394000
# lr 8.750000e-07 reg 7.500000e+03 train accuracy: 0.379184 val accuracy: 0.378000
# lr 8.750000e-07 reg 7.625000e+03 train accuracy: 0.379204 val accuracy: 0.388000
# lr 8.750000e-07 reg 8.750000e+03 train accuracy: 0.378939 val accuracy: 0.391000
# lr 8.750000e-07 reg 9.375000e+03 train accuracy: 0.379449 val accuracy: 0.389000
# lr 8.750000e-07 reg 1.000000e+04 train accuracy: 0.382224 val accuracy: 0.388000
# lr 8.750000e-07 reg 1.125000e+04 train accuracy: 0.375694 val accuracy: 0.387000
# lr 8.750000e-07 reg 1.250000e+04 train accuracy: 0.374612 val accuracy: 0.374000
# best validation accuracy achieved: 0.394000

# %%
# FOR DEBUG need to be deleted before commit
# Visualize the cross-validation results
import math
import pdb

# pdb.set_trace()

x_scatter = [x[0] for x in results]
y_scatter = [x[1] for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.tight_layout(pad=3)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.478

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_217659/551825935.py in <module>
#       9 for cls, cls_name in enumerate(classes):
#      10     idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
# ---> 11     idxs = np.random.choice(idxs, examples_per_class, replace=False)
#      12     for i, idx in enumerate(idxs):
#      13         plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 154)
# (49000, 153)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

best_val_acc = -1

learning_rates = [1e-1, 7.5e-2, 6.25e-2, 5e-2, 3.75e-2, 2.5e-2, 1e-2]
regularization_strengths = [1e-2, 1e-3]
results = {} 

data = {
    'X_train': X_train_feats,
    'y_train': y_train,
    'X_val': X_val_feats,
    'y_val': y_val,
    'X_test': X_test_feats,
    'y_test': y_test
}

for lr in learning_rates:
    for reg in regularization_strengths:
        print('train w/ learning_rate: %.2e, reg: %.2e' % (lr, reg), end = ' ')
        model = TwoLayerNet(input_dim, hidden_dim, num_classes, reg=reg)

        solver = Solver(model, data, optim_config={'learning_rate': lr}, verbose=False, num_epochs=25)
        solver.train()

        print ('achieved val_acc: %f' % (solver.best_val_acc))
        val_acc = solver.best_val_acc
        if val_acc > best_val_acc:
            print('best model updated! | old: %f, new: %f' % (best_val_acc, val_acc))
            best_val_acc = val_acc
            best_net = model
        results[lr] = solver.best_val_acc


# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# train w/ learning_rate: 1.00e-01, reg: 1.00e-02 achieved val_acc: 0.526000
# best model updated! | old: -1.000000, new: 0.526000
# train w/ learning_rate: 1.00e-01, reg: 1.00e-03 achieved val_acc: 0.513000
# train w/ learning_rate: 7.50e-02, reg: 1.00e-02 achieved val_acc: 0.517000
# train w/ learning_rate: 7.50e-02, reg: 1.00e-03 achieved val_acc: 0.519000
# train w/ learning_rate: 6.25e-02, reg: 1.00e-02 achieved val_acc: 0.524000
# train w/ learning_rate: 6.25e-02, reg: 1.00e-03 achieved val_acc: 0.514000
# train w/ learning_rate: 5.00e-02, reg: 1.00e-02 achieved val_acc: 0.515000
# train w/ learning_rate: 5.00e-02, reg: 1.00e-03 achieved val_acc: 0.512000
# train w/ learning_rate: 3.75e-02, reg: 1.00e-02 achieved val_acc: 0.515000
# train w/ learning_rate: 3.75e-02, reg: 1.00e-03 achieved val_acc: 0.517000
# train w/ learning_rate: 2.50e-02, reg: 1.00e-02 achieved val_acc: 0.517000
# train w/ learning_rate: 2.50e-02, reg: 1.00e-03 achieved val_acc: 0.515000
# train w/ learning_rate: 1.00e-02, reg: 1.00e-02 achieved val_acc: 0.515000
# train w/ learning_rate: 1.00e-02, reg: 1.00e-03 achieved val_acc: 0.520000

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.505
